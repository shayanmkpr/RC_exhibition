# %%
# Plot a random audio wave, MFCC, and Mel spectrogram
random_idx = np.random.randint(len(audio_tensors))
random_idx_2 = np.random.randint(len(audio_tensors))
random_audio = audio_tensors[random_idx].numpy()
random_mfcc = mfcc_tensors[random_idx].numpy()
random_mel = mel_tensors[random_idx].numpy()
random_mel_2 = mel_tensors[random_idx_2].numpy()

audio_reconstructed = mel_to_audio(random_mel, sample_rate)

# Plot audio waveform
plt.figure(figsize=(10, 4))
plt.plot(random_audio)
plt.title(f'Audio Waveform of Digit {labels[random_idx]}')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# Plot MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(random_mfcc.T, sr=sample_rate, x_axis='time')
plt.colorbar()
plt.title(f'MFCC of Digit {labels[random_idx]}')
plt.xlabel('Time')
plt.ylabel('MFCC Coefficients')
plt.show()

# Plot Mel spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(random_mel.T, ref=np.max), sr=sample_rate, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title(f'Mel Spectrogram of Digit {labels[random_idx]}')
plt.xlabel('Time')
plt.ylabel('Frequency (Mel)')
plt.show()

# Plot Mel spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(random_mel_2.T, ref=np.max), sr=sample_rate, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title(f'Mel Spectrogram of Digit {labels[random_idx_2]}')
plt.xlabel('Time')
plt.ylabel('Frequency (Mel)')
plt.show()

# Play the random audio file
ipd.Audio(random_audio, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
